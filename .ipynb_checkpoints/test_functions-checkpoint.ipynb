# %%
import importlib
import traceback
import inspect
import os
import sys
import pandas as pd
import nltk


sys.path.insert(0, os.getcwd())
sys.path.insert(0, os.path.join(os.getcwd(), "www", "services"))

# %%
df_openalex = pd.read_csv("test_openalex.csv")
df_pubmed = pd.read_csv("test_pubmed.csv")
print(f"OpenAlex ready: {df_openalex.shape[0]} rows, {df_openalex.shape[1]} columns")
print(f"PubMed ready: {df_pubmed.shape[0]} rows, {df_pubmed.shape[1]} columns")
# Out:
# OpenAlex ready: 50 rows, 25 columns
# PubMed ready: 50 rows, 25 columns

# %%
import ast

# Fix list columns — CSV saves lists as strings
list_cols = ["AU", "AF", "C1", "CR", "DE", "ID"]
for col in list_cols:
    df_openalex[col] = df_openalex[col].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
    df_pubmed[col] = df_pubmed[col].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

# Fix string columns — CSV saves empty strings as NaN
str_cols = ["UT", "DI", "PMID", "TI", "SO", "JI", "PY", "DT", "LA", "RP", "AB", "VL", "IS", "BP", "EP", "SR", "DB"]
for col in str_cols:
    df_openalex[col] = df_openalex[col].fillna("").astype(str)
    df_pubmed[col] = df_pubmed[col].fillna("").astype(str)

print("DataFrames ready")
# Out:
# DataFrames ready

# %%
# Change this for each function you test
MODULE = "functions.get_historiograph"
FUNCTION = "get_historiograph"


mod = importlib.import_module(MODULE)
importlib.reload(mod)

# Find the actual function name if you don't know it
for name, obj in inspect.getmembers(mod, inspect.isfunction):
    if obj.__module__ == mod.__name__:
        print(f"Function found: {name}")
        print(f"Arguments: {inspect.signature(obj)}")
# Out:
# Function found: get_historiograph
# Arguments: (df, node_label='AU1', histNodes=20, hist_isolates=True, histlabelsize=3, histsize=4, sep=';')
# Function found: hex_to_rgba
# Arguments: (hex_color, alpha)

# %%
func = getattr(mod, "get_historiograph")

importlib.reload(importlib.import_module("www.services.histnetwork"))

for source_name, df in [("OpenAlex", df_openalex), ("PubMed", df_pubmed)]:
    try:
        result = func(df.copy())
        print(f"[PASS] {source_name}")
    except Exception as e:
        print(f"[FAIL] {source_name}")
        print(traceback.format_exc())
# Out:
# WOS DB:
# Searching local citations (LCS) by reference items (SR) and DOIs...
#
#
# Analyzing 2689 reference items...
#
# [FAIL] OpenAlex
# Traceback (most recent call last):
#   File "/var/folders/m4/sy7wc1yj5q13gm65ppfn3rxr0000gq/T/ipykernel_24534/3394699719.py", line 7, in <module>
#     result = func(df.copy())
#              ^^^^^^^^^^^^^^^
#   File "/Users/isabelladilorenzi/Desktop/University/Semester 2/H&S/Project/most recent/bibliometrix-python-dev/functions/get_historiograph.py", line 40, in get_historiograph
#     raise ValueError("No citation data available for historiograph with this dataset.")
# ValueError: No citation data available for historiograph with this dataset.
#
#
# WOS DB:
# Searching local citations (LCS) by reference items (SR) and DOIs...
#
#
# Analyzing 0 reference items...
#
# [FAIL] PubMed
# Traceback (most recent call last):
#   File "/var/folders/m4/sy7wc1yj5q13gm65ppfn3rxr0000gq/T/ipykernel_24534/3394699719.py", line 7, in <module>
#     result = func(df.copy())
#              ^^^^^^^^^^^^^^^
#   File "/Users/isabelladilorenzi/Desktop/University/Semester 2/H&S/Project/most recent/bibliometrix-python-dev/functions/get_historiograph.py", line 40, in get_historiograph
#     raise ValueError("No citation data available for historiograph with this dataset.")
# ValueError: No citation data available for historiograph with this dataset.
